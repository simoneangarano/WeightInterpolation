# %% [markdown]
# # Weight Selection

# %%
import torch
import timm

# %%
def uniform_element_selection(wt, s_shape):
    assert wt.dim() == len(s_shape), "Tensors have different number of dimensions"
    ws = wt.clone()
    for dim in range(wt.dim()):
        assert wt.shape[dim] >= s_shape[dim], "Teacher's dimension should not be smaller than student's dimension"  # determine whether teacher is larger than student on this dimension
        if wt.shape[dim] % s_shape[dim] == 0:
            step = wt.shape[dim] // s_shape[dim]
            indices = torch.arange(s_shape[dim]) * step
        else:
            indices = torch.round(torch.linspace(0, wt.shape[dim], s_shape[dim]))
        ws = torch.index_select(ws, dim, indices)
    assert ws.shape == s_shape
    return ws

# %%
# ViT-T weight selection from ImageNet-21K pretrained ViT-S
teacher = timm.create_model('vit_small_patch16_224_in21k', pretrained=True)
teacher_weights = teacher.state_dict()
from models.vision_transformer import vit_tiny
student = vit_tiny()
student_weights = student.state_dict()
# ConvNeXt-F weight seletion from ImageNet-21K pretrained ConvNeXt-T
# Uncomment below for ConvNeXt
# teacher = timm.create_model('convnext_tiny_in22k', pretrained=True)
# teacher_weights = teacher.state_dict()
# from models.convnext import convnext_femto
# student = convnext_femto()
# student_weights = student.state_dict()

# %%
weight_selection = {}
for key in student_weights.keys():
    # We don't perform weight selection on classification head by default. Remove this constraint if target dataset is the same as teacher's.
    if "head" in key:
        continue
    # First-N layer selection is implicitly applied here
    weight_selection[key] = uniform_element_selection(teacher_weights[key], student_weights[key].shape)

# %%
torch.save({'model':weight_selection}, "weight_selection.pth")

# %% [markdown]
# # Weight Interpolation/Pooling

# %%
import torch
import torch.nn.functional as F
import timm
from models.vision_transformer import vit_tiny

# %%
def weight_interpolate(weight, shape, mode):
    s_len = len(shape)
    if s_len == 4:
        weight = weight.permute(3, 2, 1, 0)
        shape = shape[::-1]
    else:
        shape = torch.Size([1, shape[0]]) if s_len == 1 else shape
        while len(weight.shape) < 4:
            weight = weight.unsqueeze(0)

    ws = F.interpolate(weight, size=shape[-2:], mode=mode, align_corners=None)

    if s_len == 4:
        ws = ws.permute(3, 2, 1, 0)
    else:
        while len(ws.shape) > s_len:
            ws = ws.squeeze(0)    
    return ws

def weight_pooling(weight, shape):
    s_len = len(shape)
    if s_len == 4:
        weight = weight.permute(3, 2, 1, 0)
        shape = shape[::-1]
    else:
        shape = torch.Size([1, shape[0]]) if s_len == 1 else shape
        while len(weight.shape) < 4:
            weight = weight.unsqueeze(0)

    ws = F.interpolate(weight, size=shape[-2:], mode='bilinear', align_corners=None)
    ws = F.max_pool1d(ws, ws.shape[-1], stride=1).squeeze(-1)

    if s_len == 4:
        ws = ws.permute(3, 2, 1, 0)
    else:
        while len(ws.shape) > s_len:
            ws = ws.squeeze(0)    
    return ws

# %%
teacher = timm.create_model('vit_small_patch16_224_in21k', pretrained=True)
teacher_weights = teacher.state_dict()
student = vit_tiny()
student_weights = student.state_dict()

# %%
mode = 'nearest'
weight_selection = {}
for key in student_weights.keys():
    # We don't perform weight selection on classification head by default. Remove this constraint if target dataset is the same as teacher's.
    if "head" in key:
        continue
    # First-N layer selection is implicitly applied here
    print(key)
    print(teacher_weights[key].shape, student_weights[key].shape)
    weight_selection[key] = weight_interpolate(teacher_weights[key], student_weights[key].shape, mode=mode)
    print('Mean: ', teacher_weights[key].mean(), weight_selection[key].mean())
    print('Std: ', teacher_weights[key].std(), weight_selection[key].std())
    print('Max: ', teacher_weights[key].max(), weight_selection[key].max())
    print('Min: ', teacher_weights[key].min(), weight_selection[key].min())
    print('')
# Out:
# cls_token
# torch.Size([1, 1, 384]) torch.Size([1, 1, 192])
# Mean:  tensor(-0.0312) tensor(-0.0271)
# Std:  tensor(0.6031) tensor(0.7755)
# Max:  tensor(3.5577) tensor(3.5577)
# Min:  tensor(-6.5319) tensor(-6.5319)
#
# pos_embed
# torch.Size([1, 197, 384]) torch.Size([1, 197, 192])
# Mean:  tensor(-0.0014) tensor(-0.0015)
# Std:  tensor(0.4151) tensor(0.4453)
# Max:  tensor(4.7052) tensor(4.7052)
# Min:  tensor(-6.5487) tensor(-6.5487)
#
# patch_embed.proj.weight
# torch.Size([384, 3, 16, 16]) torch.Size([192, 3, 16, 16])
# Mean:  tensor(3.5103e-05) tensor(5.8455e-05)
# Std:  tensor(0.0465) tensor(0.0459)
# Max:  tensor(0.5049) tensor(0.5049)
# Min:  tensor(-0.4606) tensor(-0.4606)
#
# patch_embed.proj.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(-0.0030) tensor(-0.0198)
# Std:  tensor(0.2306) tensor(0.2796)
# Max:  tensor(0.9889) tensor(0.8221)
# Min:  tensor(-2.3685) tensor(-2.3685)
#
# blocks.0.norm1.weight
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(0.4652) tensor(0.4612)
# Std:  tensor(0.2491) tensor(0.2460)
# Max:  tensor(1.0041) tensor(1.0041)
# Min:  tensor(-0.0004) tensor(-0.0004)
#
# blocks.0.norm1.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(-0.0021) tensor(0.0033)
# Std:  tensor(0.1541) tensor(0.1840)
# Max:  tensor(1.7847) tensor(1.7847)
# Min:  tensor(-0.6805) tensor(-0.6805)
#
# blocks.0.attn.qkv.weight
# torch.Size([1152, 384]) torch.Size([576, 192])
# Mean:  tensor(0.0001) tensor(0.0001)
# Std:  tensor(0.0621) tensor(0.0618)
# Max:  tensor(0.4818) tensor(0.4639)
# Min:  tensor(-0.5311) tensor(-0.3867)
#
# blocks.0.attn.qkv.bias
# torch.Size([1152]) torch.Size([576])
# Mean:  tensor(-0.0097) tensor(-0.0112)
# Std:  tensor(0.6743) tensor(0.6879)
# Max:  tensor(3.1517) tensor(3.1517)
# Min:  tensor(-3.1486) tensor(-3.0406)
#
# blocks.0.attn.proj.weight
# torch.Size([384, 384]) torch.Size([192, 192])
# Mean:  tensor(0.0002) tensor(0.0002)
# Std:  tensor(0.0506) tensor(0.0507)
# Max:  tensor(0.8965) tensor(0.7350)
# Min:  tensor(-0.7268) tensor(-0.7268)
#
# blocks.0.attn.proj.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(-0.0073) tensor(-0.0006)
# Std:  tensor(0.2439) tensor(0.2818)
# Max:  tensor(2.2683) tensor(2.2683)
# Min:  tensor(-1.0177) tensor(-0.8684)
#
# blocks.0.norm2.weight
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(1.1179) tensor(1.0967)
# Std:  tensor(0.8601) tensor(0.8555)
# Max:  tensor(2.9209) tensor(2.9209)
# Min:  tensor(-0.0007) tensor(-0.0002)
#
# blocks.0.norm2.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(-0.0267) tensor(-0.0203)
# Std:  tensor(0.3089) tensor(0.3326)
# Max:  tensor(1.7547) tensor(1.7547)
# Min:  tensor(-1.6412) tensor(-1.6412)
#
# blocks.0.mlp.fc1.weight
# torch.Size([1536, 384]) torch.Size([768, 192])
# Mean:  tensor(-6.7933e-05) tensor(-6.7595e-05)
# Std:  tensor(0.0561) tensor(0.0560)
# Max:  tensor(0.7555) tensor(0.7555)
# Min:  tensor(-0.7392) tensor(-0.7392)
#
# blocks.0.mlp.fc1.bias
# torch.Size([1536]) torch.Size([768])
# Mean:  tensor(-0.9778) tensor(-0.9471)
# Std:  tensor(0.8495) tensor(0.8304)
# Max:  tensor(0.7436) tensor(0.7436)
# Min:  tensor(-3.4611) tensor(-3.3747)
#
# blocks.0.mlp.fc2.weight
# torch.Size([384, 1536]) torch.Size([192, 768])
# Mean:  tensor(-2.9817e-05) tensor(-3.1068e-05)
# Std:  tensor(0.0451) tensor(0.0446)
# Max:  tensor(0.9244) tensor(0.8788)
# Min:  tensor(-1.1510) tensor(-0.8697)
#
# blocks.0.mlp.fc2.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(0.0325) tensor(0.0191)
# Std:  tensor(0.7178) tensor(0.8096)
# Max:  tensor(4.3074) tensor(3.3303)
# Min:  tensor(-8.7884) tensor(-8.7884)
#
# blocks.1.norm1.weight
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(0.5140) tensor(0.5086)
# Std:  tensor(0.1747) tensor(0.1751)
# Max:  tensor(1.4024) tensor(1.2471)
# Min:  tensor(-0.0006) tensor(-0.0006)
#
# blocks.1.norm1.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(0.0144) tensor(0.0353)
# Std:  tensor(0.2580) tensor(0.3034)
# Max:  tensor(3.3085) tensor(3.3085)
# Min:  tensor(-1.4019) tensor(-0.5581)
#
# blocks.1.attn.qkv.weight
# torch.Size([1152, 384]) torch.Size([576, 192])
# Mean:  tensor(3.2311e-05) tensor(-0.0004)
# Std:  tensor(0.0643) tensor(0.0651)
# Max:  tensor(0.7733) tensor(0.6912)
# Min:  tensor(-0.7591) tensor(-0.7143)
#
# blocks.1.attn.qkv.bias
# torch.Size([1152]) torch.Size([576])
# Mean:  tensor(0.0070) tensor(0.0024)
# Std:  tensor(0.6219) tensor(0.6079)
# Max:  tensor(3.7569) tensor(3.5487)
# Min:  tensor(-3.9939) tensor(-3.9939)
#
# blocks.1.attn.proj.weight
# torch.Size([384, 384]) torch.Size([192, 192])
# Mean:  tensor(1.0012e-05) tensor(0.0003)
# Std:  tensor(0.0492) tensor(0.0494)
# Max:  tensor(0.3912) tensor(0.3791)
# Min:  tensor(-0.3836) tensor(-0.3297)
#
# blocks.1.attn.proj.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(-0.0022) tensor(0.0100)
# Std:  tensor(0.3935) tensor(0.4328)
# Max:  tensor(1.6262) tensor(1.6262)
# Min:  tensor(-2.2840) tensor(-2.2840)
#
# blocks.1.norm2.weight
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(0.7485) tensor(0.7340)
# Std:  tensor(0.1836) tensor(0.1732)
# Max:  tensor(2.1672) tensor(1.8452)
# Min:  tensor(0.2381) tensor(0.2656)
#
# blocks.1.norm2.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(-0.0019) tensor(0.0136)
# Std:  tensor(0.2730) tensor(0.3193)
# Max:  tensor(3.1301) tensor(3.1301)
# Min:  tensor(-1.8934) tensor(-0.5960)
#
# blocks.1.mlp.fc1.weight
# torch.Size([1536, 384]) torch.Size([768, 192])
# Mean:  tensor(-0.0001) tensor(0.0003)
# Std:  tensor(0.0554) tensor(0.0552)
# Max:  tensor(0.8585) tensor(0.8218)
# Min:  tensor(-0.9163) tensor(-0.6285)
#
# blocks.1.mlp.fc1.bias
# torch.Size([1536]) torch.Size([768])
# Mean:  tensor(-0.9677) tensor(-0.9616)
# Std:  tensor(0.5389) tensor(0.5287)
# Max:  tensor(0.2474) tensor(0.1344)
# Min:  tensor(-2.9512) tensor(-2.8456)
#
# blocks.1.mlp.fc2.weight
# torch.Size([384, 1536]) torch.Size([192, 768])
# Mean:  tensor(2.9027e-05) tensor(-4.8146e-05)
# Std:  tensor(0.0503) tensor(0.0501)
# Max:  tensor(0.8568) tensor(0.7882)
# Min:  tensor(-1.0083) tensor(-1.0083)
#
# blocks.1.mlp.fc2.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(0.0145) tensor(-0.0008)
# Std:  tensor(0.3346) tensor(0.3722)
# Max:  tensor(2.7200) tensor(0.6899)
# Min:  tensor(-3.3511) tensor(-3.3511)
#
# blocks.2.norm1.weight
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(0.7000) tensor(0.6911)
# Std:  tensor(0.1422) tensor(0.1444)
# Max:  tensor(1.3265) tensor(1.1298)
# Min:  tensor(0.1968) tensor(0.1968)
#
# blocks.2.norm1.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(0.0006) tensor(0.0158)
# Std:  tensor(0.2161) tensor(0.2666)
# Max:  tensor(3.2001) tensor(3.2001)
# Min:  tensor(-0.7010) tensor(-0.3735)
#
# blocks.2.attn.qkv.weight
# torch.Size([1152, 384]) torch.Size([576, 192])
# Mean:  tensor(-2.0904e-06) tensor(0.0003)
# Std:  tensor(0.0600) tensor(0.0603)
# Max:  tensor(0.5679) tensor(0.5679)
# Min:  tensor(-0.6123) tensor(-0.5041)
#
# blocks.2.attn.qkv.bias
# torch.Size([1152]) torch.Size([576])
# Mean:  tensor(-0.0149) tensor(-0.0101)
# Std:  tensor(0.5062) tensor(0.5411)
# Max:  tensor(3.9352) tensor(3.9352)
# Min:  tensor(-3.4898) tensor(-3.3575)
#
# blocks.2.attn.proj.weight
# torch.Size([384, 384]) torch.Size([192, 192])
# Mean:  tensor(1.1020e-05) tensor(0.0002)
# Std:  tensor(0.0477) tensor(0.0481)
# Max:  tensor(0.3877) tensor(0.3877)
# Min:  tensor(-0.2707) tensor(-0.2707)
#
# blocks.2.attn.proj.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(0.0023) tensor(0.0075)
# Std:  tensor(0.1971) tensor(0.2222)
# Max:  tensor(0.8513) tensor(0.8513)
# Min:  tensor(-2.0044) tensor(-2.0044)
#
# blocks.2.norm2.weight
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(0.8063) tensor(0.7924)
# Std:  tensor(0.1510) tensor(0.1529)
# Max:  tensor(1.6752) tensor(1.6752)
# Min:  tensor(0.0807) tensor(0.0807)
#
# blocks.2.norm2.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(-0.0083) tensor(0.0050)
# Std:  tensor(0.2128) tensor(0.2638)
# Max:  tensor(2.9515) tensor(2.9515)
# Min:  tensor(-0.8967) tensor(-0.4826)
#
# blocks.2.mlp.fc1.weight
# torch.Size([1536, 384]) torch.Size([768, 192])
# Mean:  tensor(-0.0002) tensor(-0.0002)
# Std:  tensor(0.0551) tensor(0.0552)
# Max:  tensor(0.8067) tensor(0.3878)
# Min:  tensor(-0.8976) tensor(-0.6613)
#
# blocks.2.mlp.fc1.bias
# torch.Size([1536]) torch.Size([768])
# Mean:  tensor(-1.0335) tensor(-1.0417)
# Std:  tensor(0.6041) tensor(0.6096)
# Max:  tensor(0.1693) tensor(0.1351)
# Min:  tensor(-3.3727) tensor(-3.1217)
#
# blocks.2.mlp.fc2.weight
# torch.Size([384, 1536]) torch.Size([192, 768])
# Mean:  tensor(3.5932e-05) tensor(7.4445e-05)
# Std:  tensor(0.0482) tensor(0.0481)
# Max:  tensor(1.1186) tensor(0.3896)
# Min:  tensor(-0.9197) tensor(-0.5691)
#
# blocks.2.mlp.fc2.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(0.0080) tensor(0.0065)
# Std:  tensor(0.2000) tensor(0.2176)
# Max:  tensor(1.3787) tensor(0.7280)
# Min:  tensor(-1.5032) tensor(-1.5032)
#
# blocks.3.norm1.weight
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(0.8209) tensor(0.8100)
# Std:  tensor(0.1513) tensor(0.1572)
# Max:  tensor(1.1282) tensor(1.0627)
# Min:  tensor(0.2681) tensor(0.2681)
#
# blocks.3.norm1.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(-0.0019) tensor(0.0195)
# Std:  tensor(0.2668) tensor(0.3577)
# Max:  tensor(4.7154) tensor(4.7154)
# Min:  tensor(-0.7835) tensor(-0.3458)
#
# blocks.3.attn.qkv.weight
# torch.Size([1152, 384]) torch.Size([576, 192])
# Mean:  tensor(-1.6183e-05) tensor(4.9921e-06)
# Std:  tensor(0.0568) tensor(0.0570)
# Max:  tensor(0.3770) tensor(0.3436)
# Min:  tensor(-0.3582) tensor(-0.3423)
#
# blocks.3.attn.qkv.bias
# torch.Size([1152]) torch.Size([576])
# Mean:  tensor(-0.0126) tensor(-0.0224)
# Std:  tensor(0.4735) tensor(0.4338)
# Max:  tensor(4.1919) tensor(2.9714)
# Min:  tensor(-3.7636) tensor(-3.7636)
#
# blocks.3.attn.proj.weight
# torch.Size([384, 384]) torch.Size([192, 192])
# Mean:  tensor(-2.7515e-05) tensor(-4.8232e-05)
# Std:  tensor(0.0530) tensor(0.0531)
# Max:  tensor(0.2675) tensor(0.2593)
# Min:  tensor(-0.3226) tensor(-0.3226)
#
# blocks.3.attn.proj.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(0.0071) tensor(0.0118)
# Std:  tensor(0.2398) tensor(0.2762)
# Max:  tensor(0.5972) tensor(0.5972)
# Min:  tensor(-2.6334) tensor(-2.6334)
#
# blocks.3.norm2.weight
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(0.8040) tensor(0.7975)
# Std:  tensor(0.0933) tensor(0.0939)
# Max:  tensor(1.3831) tensor(1.3831)
# Min:  tensor(0.3260) tensor(0.3260)
#
# blocks.3.norm2.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(-0.0122) tensor(0.0004)
# Std:  tensor(0.2216) tensor(0.2774)
# Max:  tensor(3.0766) tensor(3.0766)
# Min:  tensor(-0.5932) tensor(-0.4478)
#
# blocks.3.mlp.fc1.weight
# torch.Size([1536, 384]) torch.Size([768, 192])
# Mean:  tensor(-0.0002) tensor(-0.0004)
# Std:  tensor(0.0545) tensor(0.0545)
# Max:  tensor(0.4926) tensor(0.4926)
# Min:  tensor(-0.8704) tensor(-0.8704)
#
# blocks.3.mlp.fc1.bias
# torch.Size([1536]) torch.Size([768])
# Mean:  tensor(-1.0348) tensor(-1.0352)
# Std:  tensor(0.6194) tensor(0.6275)
# Max:  tensor(0.3320) tensor(0.3320)
# Min:  tensor(-3.9722) tensor(-3.9722)
#
# blocks.3.mlp.fc2.weight
# torch.Size([384, 1536]) torch.Size([192, 768])
# Mean:  tensor(3.8649e-05) tensor(0.0001)
# Std:  tensor(0.0490) tensor(0.0494)
# Max:  tensor(1.0665) tensor(1.0665)
# Min:  tensor(-0.8916) tensor(-0.8916)
#
# blocks.3.mlp.fc2.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(0.0063) tensor(0.0034)
# Std:  tensor(0.1603) tensor(0.1828)
# Max:  tensor(0.4243) tensor(0.3232)
# Min:  tensor(-1.7286) tensor(-1.7286)
#
# blocks.4.norm1.weight
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(0.7972) tensor(0.7921)
# Std:  tensor(0.1213) tensor(0.1281)
# Max:  tensor(1.2085) tensor(1.0601)
# Min:  tensor(0.2681) tensor(0.2839)
#
# blocks.4.norm1.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(-0.0108) tensor(0.0047)
# Std:  tensor(0.2289) tensor(0.2951)
# Max:  tensor(3.5958) tensor(3.5958)
# Min:  tensor(-0.6082) tensor(-0.4471)
#
# blocks.4.attn.qkv.weight
# torch.Size([1152, 384]) torch.Size([576, 192])
# Mean:  tensor(-3.4446e-05) tensor(0.0001)
# Std:  tensor(0.0563) tensor(0.0564)
# Max:  tensor(0.5114) tensor(0.5114)
# Min:  tensor(-0.5352) tensor(-0.5352)
#
# blocks.4.attn.qkv.bias
# torch.Size([1152]) torch.Size([576])
# Mean:  tensor(-0.0040) tensor(8.2559e-05)
# Std:  tensor(0.4439) tensor(0.4398)
# Max:  tensor(3.8585) tensor(3.8585)
# Min:  tensor(-4.0474) tensor(-3.6537)
#
# blocks.4.attn.proj.weight
# torch.Size([384, 384]) torch.Size([192, 192])
# Mean:  tensor(-1.8281e-06) tensor(0.0002)
# Std:  tensor(0.0526) tensor(0.0521)
# Max:  tensor(0.4405) tensor(0.3656)
# Min:  tensor(-0.3970) tensor(-0.2807)
#
# blocks.4.attn.proj.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(0.0052) tensor(0.0120)
# Std:  tensor(0.1809) tensor(0.2055)
# Max:  tensor(0.4533) tensor(0.4533)
# Min:  tensor(-1.8016) tensor(-1.8016)
#
# blocks.4.norm2.weight
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(0.7526) tensor(0.7505)
# Std:  tensor(0.0635) tensor(0.0629)
# Max:  tensor(1.0701) tensor(1.0701)
# Min:  tensor(0.2057) tensor(0.2952)
#
# blocks.4.norm2.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(-0.0143) tensor(-2.5065e-05)
# Std:  tensor(0.2270) tensor(0.2862)
# Max:  tensor(2.9845) tensor(2.9845)
# Min:  tensor(-0.6505) tensor(-0.4602)
#
# blocks.4.mlp.fc1.weight
# torch.Size([1536, 384]) torch.Size([768, 192])
# Mean:  tensor(-2.5540e-05) tensor(0.0003)
# Std:  tensor(0.0542) tensor(0.0542)
# Max:  tensor(0.5802) tensor(0.5375)
# Min:  tensor(-0.7325) tensor(-0.4281)
#
# blocks.4.mlp.fc1.bias
# torch.Size([1536]) torch.Size([768])
# Mean:  tensor(-1.0191) tensor(-1.0160)
# Std:  tensor(0.6163) tensor(0.6137)
# Max:  tensor(0.6140) tensor(0.4895)
# Min:  tensor(-4.3711) tensor(-3.5383)
#
# blocks.4.mlp.fc2.weight
# torch.Size([384, 1536]) torch.Size([192, 768])
# Mean:  tensor(4.1875e-05) tensor(8.9903e-05)
# Std:  tensor(0.0510) tensor(0.0510)
# Max:  tensor(0.7202) tensor(0.5107)
# Min:  tensor(-0.7527) tensor(-0.6118)
#
# blocks.4.mlp.fc2.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(0.0042) tensor(-0.0052)
# Std:  tensor(0.1454) tensor(0.1613)
# Max:  tensor(0.4626) tensor(0.3528)
# Min:  tensor(-1.2358) tensor(-1.2358)
#
# blocks.5.norm1.weight
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(0.7561) tensor(0.7570)
# Std:  tensor(0.1048) tensor(0.1051)
# Max:  tensor(1.1159) tensor(1.1156)
# Min:  tensor(0.2919) tensor(0.3423)
#
# blocks.5.norm1.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(-0.0058) tensor(0.0221)
# Std:  tensor(0.2362) tensor(0.3092)
# Max:  tensor(3.8496) tensor(3.8496)
# Min:  tensor(-0.5117) tensor(-0.3536)
#
# blocks.5.attn.qkv.weight
# torch.Size([1152, 384]) torch.Size([576, 192])
# Mean:  tensor(-1.1573e-05) tensor(-3.9990e-05)
# Std:  tensor(0.0559) tensor(0.0558)
# Max:  tensor(0.4199) tensor(0.4199)
# Min:  tensor(-0.4777) tensor(-0.4498)
#
# blocks.5.attn.qkv.bias
# torch.Size([1152]) torch.Size([576])
# Mean:  tensor(-0.0150) tensor(-0.0176)
# Std:  tensor(0.4597) tensor(0.4790)
# Max:  tensor(3.7969) tensor(3.7969)
# Min:  tensor(-3.9713) tensor(-3.9713)
#
# blocks.5.attn.proj.weight
# torch.Size([384, 384]) torch.Size([192, 192])
# Mean:  tensor(2.2064e-05) tensor(-1.6697e-05)
# Std:  tensor(0.0515) tensor(0.0517)
# Max:  tensor(0.3615) tensor(0.3037)
# Min:  tensor(-0.3116) tensor(-0.2980)
#
# blocks.5.attn.proj.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(0.0023) tensor(0.0047)
# Std:  tensor(0.1647) tensor(0.1691)
# Max:  tensor(0.5571) tensor(0.5571)
# Min:  tensor(-1.2067) tensor(-1.2067)
#
# blocks.5.norm2.weight
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(0.7829) tensor(0.7802)
# Std:  tensor(0.0729) tensor(0.0819)
# Max:  tensor(1.1786) tensor(0.9922)
# Min:  tensor(0.2352) tensor(0.2352)
#
# blocks.5.norm2.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(-0.0143) tensor(0.0105)
# Std:  tensor(0.2077) tensor(0.2420)
# Max:  tensor(1.8877) tensor(1.8877)
# Min:  tensor(-0.5992) tensor(-0.4583)
#
# blocks.5.mlp.fc1.weight
# torch.Size([1536, 384]) torch.Size([768, 192])
# Mean:  tensor(0.0001) tensor(-0.0002)
# Std:  tensor(0.0547) tensor(0.0547)
# Max:  tensor(0.5080) tensor(0.5080)
# Min:  tensor(-0.8206) tensor(-0.3985)
#
# blocks.5.mlp.fc1.bias
# torch.Size([1536]) torch.Size([768])
# Mean:  tensor(-1.0556) tensor(-1.0436)
# Std:  tensor(0.5821) tensor(0.5776)
# Max:  tensor(0.0606) tensor(0.0254)
# Min:  tensor(-3.2236) tensor(-3.2236)
#
# blocks.5.mlp.fc2.weight
# torch.Size([384, 1536]) torch.Size([192, 768])
# Mean:  tensor(-2.1904e-06) tensor(-3.2657e-05)
# Std:  tensor(0.0502) tensor(0.0502)
# Max:  tensor(1.1279) tensor(0.8298)
# Min:  tensor(-0.9436) tensor(-0.9097)
#
# blocks.5.mlp.fc2.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(0.0052) tensor(0.0006)
# Std:  tensor(0.1351) tensor(0.1481)
# Max:  tensor(0.4419) tensor(0.4258)
# Min:  tensor(-1.2000) tensor(-1.2000)
#
# blocks.6.norm1.weight
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(0.8054) tensor(0.8068)
# Std:  tensor(0.1172) tensor(0.1165)
# Max:  tensor(1.4172) tensor(1.1966)
# Min:  tensor(0.3350) tensor(0.3350)
#
# blocks.6.norm1.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(-0.0114) tensor(0.0135)
# Std:  tensor(0.2169) tensor(0.2605)
# Max:  tensor(2.7589) tensor(2.7589)
# Min:  tensor(-0.5297) tensor(-0.5297)
#
# blocks.6.attn.qkv.weight
# torch.Size([1152, 384]) torch.Size([576, 192])
# Mean:  tensor(-4.9338e-05) tensor(-5.7828e-05)
# Std:  tensor(0.0547) tensor(0.0547)
# Max:  tensor(0.5362) tensor(0.4608)
# Min:  tensor(-0.6379) tensor(-0.6379)
#
# blocks.6.attn.qkv.bias
# torch.Size([1152]) torch.Size([576])
# Mean:  tensor(0.0091) tensor(-0.0035)
# Std:  tensor(0.4428) tensor(0.4590)
# Max:  tensor(4.2408) tensor(4.2408)
# Min:  tensor(-3.4727) tensor(-3.4727)
#
# blocks.6.attn.proj.weight
# torch.Size([384, 384]) torch.Size([192, 192])
# Mean:  tensor(-1.7141e-05) tensor(-2.8952e-05)
# Std:  tensor(0.0546) tensor(0.0545)
# Max:  tensor(0.3936) tensor(0.3936)
# Min:  tensor(-0.3406) tensor(-0.2652)
#
# blocks.6.attn.proj.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(0.0037) tensor(0.0102)
# Std:  tensor(0.1721) tensor(0.1782)
# Max:  tensor(0.4493) tensor(0.4493)
# Min:  tensor(-1.1014) tensor(-1.1014)
#
# blocks.6.norm2.weight
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(0.8132) tensor(0.8100)
# Std:  tensor(0.0732) tensor(0.0789)
# Max:  tensor(1.0073) tensor(0.9955)
# Min:  tensor(0.2163) tensor(0.2163)
#
# blocks.6.norm2.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(-0.0135) tensor(0.0080)
# Std:  tensor(0.2511) tensor(0.2844)
# Max:  tensor(2.0345) tensor(2.0345)
# Min:  tensor(-0.6686) tensor(-0.5606)
#
# blocks.6.mlp.fc1.weight
# torch.Size([1536, 384]) torch.Size([768, 192])
# Mean:  tensor(0.0002) tensor(-0.0002)
# Std:  tensor(0.0556) tensor(0.0551)
# Max:  tensor(0.8148) tensor(0.4001)
# Min:  tensor(-1.0454) tensor(-0.8632)
#
# blocks.6.mlp.fc1.bias
# torch.Size([1536]) torch.Size([768])
# Mean:  tensor(-1.1080) tensor(-1.1218)
# Std:  tensor(0.5517) tensor(0.5470)
# Max:  tensor(0.1117) tensor(0.0239)
# Min:  tensor(-3.8927) tensor(-2.7974)
#
# blocks.6.mlp.fc2.weight
# torch.Size([384, 1536]) torch.Size([192, 768])
# Mean:  tensor(1.0007e-05) tensor(-0.0002)
# Std:  tensor(0.0567) tensor(0.0571)
# Max:  tensor(0.8227) tensor(0.8227)
# Min:  tensor(-1.1260) tensor(-1.1260)
#
# blocks.6.mlp.fc2.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(0.0038) tensor(-0.0044)
# Std:  tensor(0.1627) tensor(0.1815)
# Max:  tensor(0.6667) tensor(0.6667)
# Min:  tensor(-1.3948) tensor(-1.3948)
#
# blocks.7.norm1.weight
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(0.8120) tensor(0.8170)
# Std:  tensor(0.1177) tensor(0.1237)
# Max:  tensor(1.4409) tensor(1.4409)
# Min:  tensor(0.2717) tensor(0.2717)
#
# blocks.7.norm1.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(-0.0121) tensor(0.0095)
# Std:  tensor(0.2113) tensor(0.2376)
# Max:  tensor(2.2768) tensor(2.2768)
# Min:  tensor(-0.6441) tensor(-0.4497)
#
# blocks.7.attn.qkv.weight
# torch.Size([1152, 384]) torch.Size([576, 192])
# Mean:  tensor(-7.9948e-07) tensor(2.0568e-05)
# Std:  tensor(0.0553) tensor(0.0553)
# Max:  tensor(0.5095) tensor(0.5095)
# Min:  tensor(-0.4620) tensor(-0.4620)
#
# blocks.7.attn.qkv.bias
# torch.Size([1152]) torch.Size([576])
# Mean:  tensor(0.0107) tensor(0.0063)
# Std:  tensor(0.4814) tensor(0.5405)
# Max:  tensor(4.4666) tensor(4.4666)
# Min:  tensor(-3.5487) tensor(-3.5487)
#
# blocks.7.attn.proj.weight
# torch.Size([384, 384]) torch.Size([192, 192])
# Mean:  tensor(7.9859e-06) tensor(0.0002)
# Std:  tensor(0.0549) tensor(0.0551)
# Max:  tensor(0.3536) tensor(0.3098)
# Min:  tensor(-0.3899) tensor(-0.2702)
#
# blocks.7.attn.proj.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(0.0028) tensor(0.0058)
# Std:  tensor(0.2070) tensor(0.2480)
# Max:  tensor(0.4977) tensor(0.4947)
# Min:  tensor(-2.3476) tensor(-2.3476)
#
# blocks.7.norm2.weight
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(0.9400) tensor(0.9380)
# Std:  tensor(0.0874) tensor(0.1071)
# Max:  tensor(1.2550) tensor(1.2550)
# Min:  tensor(-0.0011) tensor(-0.0011)
#
# blocks.7.norm2.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(-0.0262) tensor(-0.0149)
# Std:  tensor(0.2517) tensor(0.2466)
# Max:  tensor(0.9121) tensor(0.9121)
# Min:  tensor(-0.9088) tensor(-0.7083)
#
# blocks.7.mlp.fc1.weight
# torch.Size([1536, 384]) torch.Size([768, 192])
# Mean:  tensor(0.0010) tensor(0.0007)
# Std:  tensor(0.0547) tensor(0.0546)
# Max:  tensor(0.3951) tensor(0.3895)
# Min:  tensor(-0.3659) tensor(-0.3329)
#
# blocks.7.mlp.fc1.bias
# torch.Size([1536]) torch.Size([768])
# Mean:  tensor(-1.1684) tensor(-1.1488)
# Std:  tensor(0.5503) tensor(0.5552)
# Max:  tensor(1.6604) tensor(1.6604)
# Min:  tensor(-3.6017) tensor(-3.2384)
#
# blocks.7.mlp.fc2.weight
# torch.Size([384, 1536]) torch.Size([192, 768])
# Mean:  tensor(3.6565e-05) tensor(0.0004)
# Std:  tensor(0.0624) tensor(0.0627)
# Max:  tensor(1.1516) tensor(1.1516)
# Min:  tensor(-0.9347) tensor(-0.9347)
#
# blocks.7.mlp.fc2.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(0.0002) tensor(-0.0105)
# Std:  tensor(0.2806) tensor(0.3734)
# Max:  tensor(0.5301) tensor(0.5301)
# Min:  tensor(-4.6934) tensor(-4.6934)
#
# blocks.8.norm1.weight
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(0.8608) tensor(0.8665)
# Std:  tensor(0.0913) tensor(0.0931)
# Max:  tensor(1.1848) tensor(1.1848)
# Min:  tensor(0.1620) tensor(0.1620)
#
# blocks.8.norm1.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(-0.0179) tensor(-0.0043)
# Std:  tensor(0.2056) tensor(0.2190)
# Max:  tensor(1.5887) tensor(1.5887)
# Min:  tensor(-0.5482) tensor(-0.4022)
#
# blocks.8.attn.qkv.weight
# torch.Size([1152, 384]) torch.Size([576, 192])
# Mean:  tensor(1.4542e-05) tensor(6.4537e-05)
# Std:  tensor(0.0557) tensor(0.0557)
# Max:  tensor(0.3682) tensor(0.3682)
# Min:  tensor(-0.4049) tensor(-0.4049)
#
# blocks.8.attn.qkv.bias
# torch.Size([1152]) torch.Size([576])
# Mean:  tensor(-0.0126) tensor(0.0143)
# Std:  tensor(0.5057) tensor(0.4986)
# Max:  tensor(3.4509) tensor(3.4509)
# Min:  tensor(-5.5381) tensor(-4.1205)
#
# blocks.8.attn.proj.weight
# torch.Size([384, 384]) torch.Size([192, 192])
# Mean:  tensor(1.1889e-05) tensor(0.0002)
# Std:  tensor(0.0573) tensor(0.0581)
# Max:  tensor(0.6661) tensor(0.5872)
# Min:  tensor(-0.7636) tensor(-0.5705)
#
# blocks.8.attn.proj.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(-0.0080) tensor(-0.0166)
# Std:  tensor(0.4902) tensor(0.6723)
# Max:  tensor(0.7795) tensor(0.6480)
# Min:  tensor(-8.8602) tensor(-8.8602)
#
# blocks.8.norm2.weight
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(2.1296) tensor(2.1278)
# Std:  tensor(0.2228) tensor(0.2719)
# Max:  tensor(3.3578) tensor(3.3578)
# Min:  tensor(0.0005) tensor(0.0005)
#
# blocks.8.norm2.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(-0.1224) tensor(-0.1188)
# Std:  tensor(0.4961) tensor(0.4972)
# Max:  tensor(1.7247) tensor(1.7247)
# Min:  tensor(-1.7971) tensor(-1.7293)
#
# blocks.8.mlp.fc1.weight
# torch.Size([1536, 384]) torch.Size([768, 192])
# Mean:  tensor(0.0031) tensor(0.0030)
# Std:  tensor(0.0557) tensor(0.0561)
# Max:  tensor(0.3507) tensor(0.3115)
# Min:  tensor(-0.4816) tensor(-0.4816)
#
# blocks.8.mlp.fc1.bias
# torch.Size([1536]) torch.Size([768])
# Mean:  tensor(-1.1622) tensor(-1.1700)
# Std:  tensor(0.6005) tensor(0.5961)
# Max:  tensor(1.9262) tensor(0.0874)
# Min:  tensor(-3.5197) tensor(-3.5197)
#
# blocks.8.mlp.fc2.weight
# torch.Size([384, 1536]) torch.Size([192, 768])
# Mean:  tensor(0.0002) tensor(0.0003)
# Std:  tensor(0.0585) tensor(0.0593)
# Max:  tensor(1.5101) tensor(1.5101)
# Min:  tensor(-0.7150) tensor(-0.7150)
#
# blocks.8.mlp.fc2.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(-0.0090) tensor(-0.0443)
# Std:  tensor(0.6419) tensor(0.8822)
# Max:  tensor(0.6713) tensor(0.6713)
# Min:  tensor(-11.7054) tensor(-11.7054)
#
# blocks.9.norm1.weight
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(0.9681) tensor(0.9694)
# Std:  tensor(0.0879) tensor(0.0987)
# Max:  tensor(1.3713) tensor(1.3713)
# Min:  tensor(0.1201) tensor(0.1201)
#
# blocks.9.norm1.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(-0.0263) tensor(-0.0160)
# Std:  tensor(0.2100) tensor(0.2236)
# Max:  tensor(1.4571) tensor(1.4571)
# Min:  tensor(-0.6521) tensor(-0.4645)
#
# blocks.9.attn.qkv.weight
# torch.Size([1152, 384]) torch.Size([576, 192])
# Mean:  tensor(-8.1237e-05) tensor(0.0002)
# Std:  tensor(0.0558) tensor(0.0558)
# Max:  tensor(0.3664) tensor(0.3375)
# Min:  tensor(-0.3180) tensor(-0.3094)
#
# blocks.9.attn.qkv.bias
# torch.Size([1152]) torch.Size([576])
# Mean:  tensor(-0.0006) tensor(0.0195)
# Std:  tensor(0.5032) tensor(0.5339)
# Max:  tensor(4.5492) tensor(4.5492)
# Min:  tensor(-4.6640) tensor(-3.4802)
#
# blocks.9.attn.proj.weight
# torch.Size([384, 384]) torch.Size([192, 192])
# Mean:  tensor(-3.5287e-05) tensor(-1.1316e-05)
# Std:  tensor(0.0601) tensor(0.0605)
# Max:  tensor(0.4245) tensor(0.4245)
# Min:  tensor(-0.4956) tensor(-0.3646)
#
# blocks.9.attn.proj.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(-0.0068) tensor(-0.0180)
# Std:  tensor(0.4540) tensor(0.6205)
# Max:  tensor(0.7086) tensor(0.7086)
# Min:  tensor(-8.1952) tensor(-8.1952)
#
# blocks.9.norm2.weight
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(3.2504) tensor(3.2622)
# Std:  tensor(0.3262) tensor(0.4113)
# Max:  tensor(5.3233) tensor(5.3233)
# Min:  tensor(0.0016) tensor(0.0016)
#
# blocks.9.norm2.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(-0.1704) tensor(-0.1797)
# Std:  tensor(0.6668) tensor(0.6694)
# Max:  tensor(2.0069) tensor(2.0069)
# Min:  tensor(-2.4419) tensor(-1.6885)
#
# blocks.9.mlp.fc1.weight
# torch.Size([1536, 384]) torch.Size([768, 192])
# Mean:  tensor(0.0033) tensor(0.0036)
# Std:  tensor(0.0588) tensor(0.0588)
# Max:  tensor(0.3500) tensor(0.2846)
# Min:  tensor(-0.2914) tensor(-0.2691)
#
# blocks.9.mlp.fc1.bias
# torch.Size([1536]) torch.Size([768])
# Mean:  tensor(-1.1632) tensor(-1.1566)
# Std:  tensor(0.6430) tensor(0.6454)
# Max:  tensor(2.2845) tensor(2.2845)
# Min:  tensor(-3.9805) tensor(-3.9805)
#
# blocks.9.mlp.fc2.weight
# torch.Size([384, 1536]) torch.Size([192, 768])
# Mean:  tensor(5.7919e-05) tensor(0.0004)
# Std:  tensor(0.0638) tensor(0.0638)
# Max:  tensor(0.6909) tensor(0.3768)
# Min:  tensor(-0.8772) tensor(-0.8772)
#
# blocks.9.mlp.fc2.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(0.0035) tensor(-0.0137)
# Std:  tensor(0.3829) tensor(0.4180)
# Max:  tensor(1.0390) tensor(0.9295)
# Min:  tensor(-3.0359) tensor(-3.0359)
#
# blocks.10.norm1.weight
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(1.1606) tensor(1.1603)
# Std:  tensor(0.1139) tensor(0.1306)
# Max:  tensor(1.7994) tensor(1.7994)
# Min:  tensor(0.0924) tensor(0.0924)
#
# blocks.10.norm1.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(-0.0379) tensor(-0.0293)
# Std:  tensor(0.2790) tensor(0.2827)
# Max:  tensor(1.1943) tensor(1.1943)
# Min:  tensor(-0.9987) tensor(-0.8225)
#
# blocks.10.attn.qkv.weight
# torch.Size([1152, 384]) torch.Size([576, 192])
# Mean:  tensor(1.0782e-06) tensor(0.0003)
# Std:  tensor(0.0566) tensor(0.0565)
# Max:  tensor(0.4815) tensor(0.2979)
# Min:  tensor(-0.2916) tensor(-0.2751)
#
# blocks.10.attn.qkv.bias
# torch.Size([1152]) torch.Size([576])
# Mean:  tensor(0.0301) tensor(0.0027)
# Std:  tensor(0.4525) tensor(0.4451)
# Max:  tensor(4.3024) tensor(3.9715)
# Min:  tensor(-4.9600) tensor(-4.9600)
#
# blocks.10.attn.proj.weight
# torch.Size([384, 384]) torch.Size([192, 192])
# Mean:  tensor(7.2744e-06) tensor(-7.2185e-05)
# Std:  tensor(0.0620) tensor(0.0618)
# Max:  tensor(0.2997) tensor(0.2686)
# Min:  tensor(-0.3033) tensor(-0.3033)
#
# blocks.10.attn.proj.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(-0.0030) tensor(0.0131)
# Std:  tensor(0.3333) tensor(0.3791)
# Max:  tensor(3.5027) tensor(3.5027)
# Min:  tensor(-0.8693) tensor(-0.6980)
#
# blocks.10.norm2.weight
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(8.5047) tensor(8.5555)
# Std:  tensor(0.8383) tensor(1.0045)
# Max:  tensor(13.6487) tensor(13.6487)
# Min:  tensor(0.5024) tensor(0.5024)
#
# blocks.10.norm2.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(-0.2357) tensor(-0.2011)
# Std:  tensor(2.3051) tensor(2.3674)
# Max:  tensor(6.9203) tensor(6.9203)
# Min:  tensor(-5.7951) tensor(-4.6027)
#
# blocks.10.mlp.fc1.weight
# torch.Size([1536, 384]) torch.Size([768, 192])
# Mean:  tensor(0.0015) tensor(0.0010)
# Std:  tensor(0.0659) tensor(0.0660)
# Max:  tensor(0.3864) tensor(0.3496)
# Min:  tensor(-0.4623) tensor(-0.3098)
#
# blocks.10.mlp.fc1.bias
# torch.Size([1536]) torch.Size([768])
# Mean:  tensor(-1.3050) tensor(-1.2962)
# Std:  tensor(0.5443) tensor(0.5278)
# Max:  tensor(1.9661) tensor(1.6678)
# Min:  tensor(-5.3567) tensor(-2.7453)
#
# blocks.10.mlp.fc2.weight
# torch.Size([384, 1536]) torch.Size([192, 768])
# Mean:  tensor(-9.0021e-05) tensor(0.0002)
# Std:  tensor(0.0762) tensor(0.0767)
# Max:  tensor(0.7649) tensor(0.5321)
# Min:  tensor(-0.7169) tensor(-0.6167)
#
# blocks.10.mlp.fc2.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(0.0096) tensor(0.0157)
# Std:  tensor(0.6856) tensor(0.7272)
# Max:  tensor(5.2679) tensor(5.2679)
# Min:  tensor(-1.6908) tensor(-1.5908)
#
# blocks.11.norm1.weight
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(1.3967) tensor(1.3995)
# Std:  tensor(0.1229) tensor(0.1378)
# Max:  tensor(2.2512) tensor(2.2512)
# Min:  tensor(0.2733) tensor(0.2733)
#
# blocks.11.norm1.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(-0.0358) tensor(-0.0331)
# Std:  tensor(0.4497) tensor(0.4569)
# Max:  tensor(2.2346) tensor(2.2346)
# Min:  tensor(-1.3997) tensor(-1.0523)
#
# blocks.11.attn.qkv.weight
# torch.Size([1152, 384]) torch.Size([576, 192])
# Mean:  tensor(-0.0001) tensor(-0.0002)
# Std:  tensor(0.0564) tensor(0.0564)
# Max:  tensor(0.3492) tensor(0.3300)
# Min:  tensor(-0.3710) tensor(-0.3052)
#
# blocks.11.attn.qkv.bias
# torch.Size([1152]) torch.Size([576])
# Mean:  tensor(0.0121) tensor(0.0297)
# Std:  tensor(0.4220) tensor(0.3941)
# Max:  tensor(3.2612) tensor(3.0071)
# Min:  tensor(-3.2537) tensor(-1.2941)
#
# blocks.11.attn.proj.weight
# torch.Size([384, 384]) torch.Size([192, 192])
# Mean:  tensor(-1.8078e-05) tensor(-0.0001)
# Std:  tensor(0.0680) tensor(0.0689)
# Max:  tensor(0.4950) tensor(0.3333)
# Min:  tensor(-0.4401) tensor(-0.3737)
#
# blocks.11.attn.proj.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(-0.0043) tensor(0.0839)
# Std:  tensor(1.2064) tensor(1.6571)
# Max:  tensor(22.1255) tensor(22.1255)
# Min:  tensor(-1.1896) tensor(-1.1896)
#
# blocks.11.norm2.weight
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(1.1573) tensor(1.1582)
# Std:  tensor(0.0899) tensor(0.1065)
# Max:  tensor(1.8396) tensor(1.8396)
# Min:  tensor(0.2962) tensor(0.2962)
#
# blocks.11.norm2.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(-0.0166) tensor(-0.0143)
# Std:  tensor(0.4312) tensor(0.4296)
# Max:  tensor(2.1017) tensor(2.1017)
# Min:  tensor(-1.4638) tensor(-1.0151)
#
# blocks.11.mlp.fc1.weight
# torch.Size([1536, 384]) torch.Size([768, 192])
# Mean:  tensor(-9.8473e-05) tensor(-0.0004)
# Std:  tensor(0.0565) tensor(0.0563)
# Max:  tensor(0.4473) tensor(0.4473)
# Min:  tensor(-0.3756) tensor(-0.2961)
#
# blocks.11.mlp.fc1.bias
# torch.Size([1536]) torch.Size([768])
# Mean:  tensor(-1.1467) tensor(-1.1460)
# Std:  tensor(0.4575) tensor(0.4690)
# Max:  tensor(2.3213) tensor(1.4756)
# Min:  tensor(-2.5335) tensor(-2.5335)
#
# blocks.11.mlp.fc2.weight
# torch.Size([384, 1536]) torch.Size([192, 768])
# Mean:  tensor(0.0001) tensor(8.7679e-05)
# Std:  tensor(0.0671) tensor(0.0674)
# Max:  tensor(1.5115) tensor(1.5115)
# Min:  tensor(-0.9916) tensor(-0.6475)
#
# blocks.11.mlp.fc2.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(-0.0611) tensor(-0.0401)
# Std:  tensor(0.7187) tensor(0.8378)
# Max:  tensor(8.6705) tensor(8.6705)
# Min:  tensor(-1.4223) tensor(-1.2298)
#
# norm.weight
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(2.2272) tensor(2.2423)
# Std:  tensor(0.3107) tensor(0.3881)
# Max:  tensor(5.2155) tensor(5.2155)
# Min:  tensor(0.4788) tensor(0.4788)
#
# norm.bias
# torch.Size([384]) torch.Size([192])
# Mean:  tensor(-0.0028) tensor(0.0039)
# Std:  tensor(0.7225) tensor(0.8099)
# Max:  tensor(6.4771) tensor(6.4771)
# Min:  tensor(-1.8754) tensor(-1.4665)

# %%
wt = torch.rand((384, 3, 16, 16))
shape = torch.Size([192, 3, 16, 16])

# %%
wt = torch.rand((1, 1, 384))
shape = torch.Size([1, 1, 192])

# %%
wt = torch.rand((1152, 384))
shape = torch.Size([576, 192])

# %%
wt = torch.rand((384))
shape = torch.Size([192])

# %%
ws = weight_interpolate(wt, shape)
ws.shape
